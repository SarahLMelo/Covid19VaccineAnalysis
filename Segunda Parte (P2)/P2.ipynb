# %% [markdown]
# # Analysis of vaccine impact in COVID-19 pandemic

# %% [markdown]
# **Group:**
#
# 1. João Guilherme Monteiro de Souza Filho (jgmsf);
# 2. Mateus Elias de Andrade Pereira (meap);
# 3. Nathalia Fernanda de Araújo Barbosa (nfab);
# 4. Sarah Leitão Melo (slm2).

# %% [markdown]
# ## Abstract

# %% [markdown]
# Our project objective is to use the SVIRS epidemic model to project two different situations: the first one is how would be the COVID-19 situation in Pernambuco if the vaccines against COVID-19 didn't exist, and the second will be a real projection of how the situation of COVID-19 in Pernambuco will develop after considering all the vaccines that we already have. Our idea is to compare these two projections to measure somehow the impact of the vaccines in the Pernambuco's COVID-19 pandemic.

# %% [markdown]
# ## Introduction and objectives

# %% [markdown]
# The COVID-19 is a disease that made its first appearence in Wuhan, China. It had its first victims in late 2019 when it was still called "Acute Respiratory Distress Syndrome". As a result of COVID's high infectious and mortality rates, it started to spread worldwide and a global effort to fight against it was needed. Scientists of all different places joined efforts in an unprecedented international collaboration to find a vaccine or a cure.
#
# Unfortunately, covid pandemic has changed the world for almost two years already. The way we work, study and live in society had to adapt to control the spreading of the virus. Besides, many lives have been lost due to the disease, impacting not only socially but also reducing the life expectancy in some countries.
#
# The vaccine against COVID-19 was developed in record time. In Pernambuco, where we are analyzing, the vaccine took a bit longer to start distribuction: it only started in January 2021. We're aiming to project two different situations, one is how would be the COVID-19 situation in Pernambuco after August/2022 if the vaccines against COVID-19 didn't exist, and the other is a real projection of how will be the situation of COVID-19 in Pernambuco after August/2022 considering all the vaccines that we have. After these two projections, we're going to analyze and report the impact of the vaccines on the COVID-19 situation in Pernambuco.
#
# Even though these vaccines have already saved millions of lives worldwide, some organizations still insist on an unscientific approach, spreading fake news and manipulating data to spread fear in the general population and influence some governments. Therefore, our main objective is to show what might have happened in a world without the fast development of vaccines, and consequently spread the danger these organizations are putting our community through.

# %% [markdown]
# ## Mind Map

# %%
URL = "https://raw.githubusercontent.com/SarahLMelo/Covid19VaccineAnalysis/main/Primeira%20Parte%20(P1)/Mind%20Map.jpg?token=GHSAT0AAAAAABWBDR4R3A2KVUIRAPUZWXOCYYZHJ6A"
response = requests.get(URL)
open("Mind Map.jpg", "wb").write(response.content)

from IPython.display import Image
Image('/content/Mind Map.jpg')

# %% [markdown]
# ## Model
# We are using the **SVIRS** model to make our two projections described in the introduction section.

# %% [markdown]
# #### SVIRS model

# %% [markdown]
# This model is a variant of **SIR's** model that includes a new group to describe the population: the vaccinated. The **SVIRS** model also considers the possibility of reinfection. That means the acquired immunity after being vaccinated or after recovering from the disease is not lifelong. Therefore this person can return to the susceptibles group and be infected again.
#
# In the **SVIRS** model, the total population is separated into three groups:
#
# * **Susceptibles $S(t)$**: individuals that can be part of the infected group.
# * **Vaccinated $V(t)$**: individuals vaccinated with two doses. They have less chance of being infected.
# * **Infected $I(t)$**: individuals infected with the disease.
# * **Recovered $R(t)$**: individuals who were infected but now recovered, having a period of immunity before becoming susceptible again. That is one of the differences between the **SVIRS** model to the SIR. In the SIR, the recovered have lifelong immunity and cannot become susceptible again.
#
# So the total population is described as:
#
# \begin{align}
# N(t) = S(t) + V(t) + I(t) + R(t)
# \end{align}
#
# This model is described by the following ODEs:
#
# \begin{align}
# \frac{{\rm d}S}{{\rm d}t} & = \omega_rR - λS + \omega_vV - \phi S &\\ \\
# \frac{{\rm d}V}{{\rm d}t} & = -(1 - ψ)λV - \omega_vV + \phi S \\ \\
# \frac{{\rm d}I}{{\rm d}t} & = λS + (1 - ψ)λV - γI \\ \\
# \frac{{\rm d}R}{{\rm d}t} & = γI - ω_rR
# \end{align}
#
# Where:
#
# 1. $λ$ represents the infection rate per person and it is defined by $λ = \frac{βI}{N}$.
# 2. $β$ represents the probability of transmitting the disease between an susceptible and a infected individual.
# 3. $γ$ represents the recorvery rate and it is determined by $γ = \frac{1}{D}$ where $D$ is the average duration of inffection in days.
# 4. $\omega_r$ represents the rate that a recovered individual comeback to susceptibles' group because of immunity loss.
# 5. $\omega_v$ represents the rate that vaccinated individuals comeback do succeptibles' group because of immunity loss.
# 6. $\phi$ represents the vaccination rate.
# 7. $ψ$ represents the vaccine efficieny rate.

# %% [markdown]
# ##### Parameters

# %% [markdown]
# To analyze each modeled scenario, we must adjust the model parameters. The vaccine efficiency varies according to the laboratory (CoronaVac, AstraZeneca, Pfizer, and Janssen). We will consider a weighted average of these different coronavirus vaccines to have better precision. Using the government of the state of Pernambuco and the vaccine efficiency by the laboratory, we have the following analysis:

# %% [markdown]
# ###### Average Efficiency Calculation → $ψ$

# %% [markdown]
# Coronavac → 4.481.720 distributed doses → $P_c = 31,25\%$
#
# > Efficiency: $\psi_c = 67,4\%$
#
# Astrazeneca → 4.707.170 distributed doses → $P_a = 32,83\%$
#
# > Efficiency: $\psi_a = 76\%$
#
# Pfizer → 4.977.180 distributed doses → $P_p = 34,71\%$
#
# > Efficiency: $\psi_p = 83,5\%$
#
# Janssen → 173.810 distributed doses → $P_j = 1,21\%$
#
# > Efficiency: $\psi_j = 66\%$
#
# **Total of distributed doses → 14.339.880**
#
# Where $P$ é a porcentagem de doses no total de doses e  é a eficácia da vacina de determinado laboratório.
#
# Where $P$ is the percentage
#
# Thus, the average effectiveness of vaccines is given by:
#
# \begin{align}
# ψ = \frac{ψ_cP_c + ψ_aP_a + ψ_pP_p + ψ_jP_j}{100\%}
# \end{align}
#
# \begin{align}
# ψ = \frac{0,674(31,25\%) + 0,76(32,83\%) + 0,835(34,71\%) + 0,66(1,21\%)}{100\%} = 0,7579475
# \end{align}
#
# \begin{align}
# ψ = 0,76
# \end{align}

# %% [markdown]
# ###### Calculation of $ω_v$, $\omega_r$ e $\phi$

# %% [markdown]
# To find the immunity loss rates (by the vaccination and by the disease recover) and the vaccination, we transformed the annual or monthly rates in daily rates.
#
# It is estimated that immunity from vaccination drops $\omega_v$ 50% per year, so we calculate that this rate is 0.1170% per day.
#
# The immunity acquired after recovery from the COVID $\omega_r$ drops 10% every 90 days, so we calculate that this rate is 0.1897% per day.
#
# To calculate the daily vaccination rate $\phi$, we consider that this vaccination was done evenly during the days, so, knowing the number of vaccinated on 31/10/2021 and the day of the vaccination start, we calculate that this rate is 0.2627% per day.

# %% [markdown]
# ###### Calculation of $β$

# %% [markdown]
# The disease transmission rate $β$ can be calculated from the spread rate of COVID-19 in the population $r$ and the number of susceptible people $S$ as follows:

# %% [markdown]
# \begin{align}
# β = \frac{r}{S}
# \end{align}

# %% [markdown]
# The spread rate $r$ was found from the analysis of the spread rates of the disease in reality considering the waves that occurred in the number of cases over time. The reference to this information is in the references section.

# %% [markdown]
# ## Results and discussion

# %% [markdown]
# Initially, we are going to analyze and plot the real data about COVID-19 in the state of Pernambuco by using graphics in order to use this information to compare posteriorly with our model results.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import requests
from scipy.integrate import odeint

# %% [markdown]
# After importing the cell above, we already have the needed libs. Now, we are going to download our dataset. One of them is the data related to COVID-19 in Pernambuco, and the other one has the data about the vaccination against COVID-19 in the state.

# %%
# In the code below we will download our datasets. One contains data on COVID-19 in PE and the other contains data on vaccination against COVID-19 in PE
URL = "https://raw.githubusercontent.com/SarahLMelo/Covid19VaccineAnalysis/main/covid19_dataset.csv?token=GHSAT0AAAAAABWBDR4QRAVW62DGTKNQIQH2Y23JILQ"
response = requests.get(URL)
open("covid19_dataset.csv", "wb").write(response.content)

URL = "https://raw.githubusercontent.com/SarahLMelo/Covid19VaccineAnalysis/main/vaccines_dataset.csv?token=GHSAT0AAAAAABWBDR4QBJJZ3RAHUWSHCI3CY23JIXQ"
response = requests.get(URL)
open("vaccines_dataset.csv", "wb").write(response.content)

# Now we will extract the data from our datasets (which are .CSV files) and store them in Pandas DataFrames
covid19_dataset = pd.read_csv('/content/covid19_dataset.csv', sep=',', on_bad_lines='skip')
vaccines_dataset = pd.read_csv('/content/vaccines_dataset.csv', sep=',', on_bad_lines='skip')

# %% [markdown]
# These are the data about COVID-19 in Pernambuco:

# %%
covid19_dataset.head()
# Out:
#   dt_referencia  dt_atualizacao  confirmados  obitos  tx_obitos  recuperados  \
# 0    2020-04-03             NaN          176      14      0.080           23
# 1    2020-04-04             NaN          201      21      0.104           25
# 2    2020-04-05             NaN          223      30      0.134           25
# 3    2020-04-06             NaN          352      34      0.097           32
# 4    2020-04-07             NaN          401      46      0.115           32
#
#    tx_recuperados  isolamento  tx_isolamento  enfermaria  tx_enfermaria  uti  \
# 0           0.131          87          0.569          34          0.222   18
# 1           0.124          87          0.494          49          0.278   19
# 2           0.112         101          0.510          44          0.222   23
# 3           0.091         166          0.519          94          0.294   26
# 4           0.080         189          0.512         110          0.298   24
#
# ...

# %% [markdown]
# These are the data about the vaccination against COVID-19 in Pernambuco:

# %%
vaccines_dataset.tail()
# Out:
#           data  primeira_dose  segunda_dose_mais_unica  dose_de_reforco
# 15  22/04/2022        8163523                  7157934          3326161
# 16  22/05/2022        8235967                  7331420          3646666
# 17  22/06/2022        8270902                  7440733          3929647
# 18  22/07/2022        8357608                  7598411          4305978
# 19  22/08/2022        8428998                  7671341          4405921

# %% [markdown]
# Firstly, we will explore the data about COVID-19 in PE, which is already in Pandas' data frame.

# %%
# We will store in a list the dates referring to each data line of our CSV with data about COVID-19 in PE
dates_covid19_dataset = mdates.datestr2num(covid19_dataset['dt_referencia'].tolist())

# Now let's filter the data about the total accumulated of confirmed cases (total accumulated infected)
totalOfInfecteds = covid19_dataset['confirmados'].tolist()

# Plotting the data (total accumulated of COVID-19 infected between April 2020 and August 2022 in PE)
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, totalOfInfecteds)
plt.xlabel("Date")
plt.ylabel("Total accumulated of infected")
# Out:
# Text(0, 0.5, 'Total accumulated of infected')

# %%
# Now let's filter the data about the total accumulated of deaths
totalOfDeaths = covid19_dataset['obitos'].tolist()

# Plotting the data (total accumulated of COVID-19 deaths between April 2020 and August 2022 in PE)
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, totalOfDeaths)
plt.xlabel("Dates")
plt.ylabel("Total accumulated of deaths")
# Out:
# Text(0, 0.5, 'Total accumulated of deaths')

# %%
# Finally, let's filter the total accumulated of recovered
totalOfRecovereds = covid19_dataset['recuperados'].tolist()

# Plotting the data (total accumulated of COVID-19 recovered between April 2020 and August 2022 in PE)
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, totalOfRecovereds)
plt.xlabel("Date")
plt.ylabel("Total of recovereds")
# Out:
# Text(0, 0.5, 'Total of recovereds')

# %%
# Now let's plot a graph containing the total accumulated of infected, recovered and dead
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, totalOfInfecteds, label="Total accumulated of infected")
plt.plot(dates_covid19_dataset, totalOfRecovereds, label="Total accumulated of recovered")
plt.plot(dates_covid19_dataset, totalOfDeaths, label="Total accumulated of deaths")

plt.yticks(range(0,1000000,100000))

plt.xlabel("Date")
plt.legend()

# %% [markdown]
# Secondly, we are going to plot and analyze the data about the vaccination against COVID-19 in PE.

# %%
# We will store in a list the dates referring to each data line of our CSV with data on vaccination against COVID-19 in PE
dates_vaccinated_dataset = mdates.datestr2num(vaccines_dataset['data'].tolist())

# Now let's filter the data about the total of first doses applied
firstDose = vaccines_dataset['primeira_dose'].tolist()

# Plotting the data (total of first doses applied against COVID-19 between January 2021 and August 2022 in PE)
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(12)
fig.set_figheight(4)

plt.plot(dates_vaccinated_dataset, firstDose)
plt.xlabel("Date")
plt.ylabel("Total of first doses applied")
# Out:
# Text(0, 0.5, 'Total of first doses applied')

# %%
# Now let's filter the data about the total of second doses + single doses applied
secondDosePlusUnique = vaccines_dataset['segunda_dose_mais_unica'].tolist()

# Plotting the data (total of second doses + single doses applied against COVID-19 between January 2021 and August 2022 in PE)
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(12)
fig.set_figheight(4)

plt.plot(dates_vaccinated_dataset, secondDosePlusUnique)
plt.xlabel("Dates")
plt.ylabel("Total of second doses + single doses applied")
# Out:
# Text(0, 0.5, 'Total of second doses + single doses applied')

# %%
# Now let's filter the data about the total of booster doses applied 
reinforcementDose = vaccines_dataset['dose_de_reforco'].tolist()

# Plotting the data (total of booster doses applied against COVID-19 between January 2021 and August 2022 in PE)
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(12)
fig.set_figheight(4)

plt.plot(dates_vaccinated_dataset, reinforcementDose)
plt.xlabel("Dates")
plt.ylabel("Total of reinforcement doses applied")
# Out:
# Text(0, 0.5, 'Total of reinforcement doses applied')

# %%
# Now let's plot a graph containing the total of first doses applied, second doses + single doses applied and booster doses applied
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(12)
fig.set_figheight(4)

plt.plot(dates_vaccinated_dataset, firstDose, label="Total of first doses applied")
plt.plot(dates_vaccinated_dataset, secondDosePlusUnique, label="Total of second doses + unique doses applied")
plt.plot(dates_vaccinated_dataset, reinforcementDose, label="Total of reinforcement doses applied")

plt.xlabel("Date")
plt.legend()

# %%
# Total of vaccines applied against COVID-19 between January 2021 and August 2022 in PE
firsDosePlusReinforcementDose = np.add(firstDose, reinforcementDose)
totalOfVaccines = np.add(secondDosePlusUnique, firsDosePlusReinforcementDose)

fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_vaccinated_dataset, totalOfVaccines, label="Total of vaccines applied")

plt.xlabel("Date")
plt.legend()

# %% [markdown]
# ### Using SVIRS model

# %% [markdown]
# We are using the odeint function of Python scientific lib called scipy to integrate the system of differential equations in time $dt$ = 1,0/1440. In the studied cases, we considered the recovery time as $D$ = 15 days. Let's assume this parameter is steady and does not change over time. Besides the parameters explained above, our initial values are:

# %% [markdown]
# \begin{align}
# N = 9674793
# \end{align}
# \begin{align}
# V_0 = 0
# \end{align}
# \begin{align}
# I_0 = 14226
# \end{align}
# \begin{align}
# R_0 = 41925
# \end{align}
# \begin{align}
# S_0 = N - I_0 - R_0 - V_0
# \end{align}

# %% [markdown]
# Now, we will apply our model to explain the pandemic behavior and plot some scenarios of COVID-19 in Pernambuco.

# %%
# Defining the initial conditions
N = 9674793
V0, I0, R0 = 0, 14226, 41925
S0 = N - I0 - R0 - V0

omegaV = 0.001170 # Vaccine immunity's drops 50% per year
omegaR = 0.001897 # The immunity of recovered people drops 10% every 90 days

psi = 0.76 # Vaccine effectiveness
phi = 0.002627 # Vaccination rate

D = 15 # Infection lasts 15 days
gamma = 1./D

# %% [markdown]
# As our initial conditions are defined, we are now going to define our model **SVIRS** and apply it.

# %%
# SVIRS model

def deriv(y, t, omegaR, omegaV, psi, phi, gamma):
    if t < 219: # until 05/02/2021 there was no vaccination - second dose, so all data related to it are 0
      phi, V, omegaV, psi = 0, 0, 0, 0
    if t < 70: # mid August 2020
      r = 0.069
    elif t < 160: # mid November 2020
      r = 0.06
    elif t < 170: # end of November 2020
      r = 0.13
    elif t < 380: # end of April 2021
      r = 0.069
    else:
      r = 0.053

    S, V, I, R = y
    beta = r/S
    
    lbda = beta

    dSdt = omegaR*R - lbda*S*I + omegaV*V - phi*S
    dVdt = (psi - 1)*lbda*V*I - omegaV*V + phi*S
    dIdt = lbda*S*I + (1 - psi)*lbda*V*I - gamma*I
    dRdt = gamma*I - omegaR*R

    return dSdt, dVdt, dIdt, dRdt

# %%
# Applying the model:
y0 = S0, V0, I0, R0
t = np.linspace(0,len(dates_covid19_dataset),len(dates_covid19_dataset))

ret = odeint(deriv, y0, t, args=(omegaR, omegaV, psi, phi, gamma))
S, V, I, R = ret.T

# %%
# Graphically representing the total accumulated of infected and comparing with reality
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, (I+R),'b', lw=2, label = 'Total accumulated of infected (model)')
plt.plot(dates_covid19_dataset, totalOfInfecteds,'m', lw=2, label = 'Total accumulated of infected (reality)')
plt.legend()
plt.show()

# %%
# Graphically representing the total accumulated of recovered and comparing with reality
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, (R),'b', lw=2, label = 'Total accumulated of recovered (model)')
plt.plot(dates_covid19_dataset, totalOfInfecteds,'m', lw=2, label = 'Total accumulated of recovered (reality)')
plt.legend()
plt.show()

# %% [markdown]
# Now we'll use our model to project the cumulative total infected and recovered up to January 2023. Basically, we are going to extend the range of our model to the last day of January 2023, using the same initial conditions. As we can see above, the results we got are quite similar to the reality of COVID-19 in PE, so our projection should be accurate.

# %%
t = np.linspace(0,len(dates_covid19_dataset)+162,len(dates_covid19_dataset)+162)

ret = odeint(deriv, y0, t, args=(omegaR, omegaV, psi, phi, gamma))
S, V, I, R = ret.T

# %%
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

appendDates = ['2022-08-23', '2022-08-24', '2022-08-25','2022-08-26','2022-08-27','2022-08-28','2022-08-29','2022-08-30','2022-08-31','2022-09-01','2022-09-02','2022-09-03','2022-09-04','2022-09-05','2022-09-06','2022-09-07','2022-09-08','2022-09-09','2022-09-10','2022-09-11','2022-09-12','2022-09-13','2022-09-14','2022-09-15','2022-09-16','2022-09-17','2022-09-18','2022-09-19','2022-09-20','2022-09-21','2022-09-22','2022-09-23','2022-09-24','2022-09-25','2022-09-26','2022-09-27','2022-09-28','2022-09-29','2022-09-30','2022-10-01','2022-10-02','2022-10-03','2022-10-04','2022-10-05','2022-10-06','2022-10-07','2022-10-08','2022-10-09','2022-10-10','2022-10-11','2022-10-12','2022-10-13','2022-10-14','2022-10-15','2022-10-16','2022-10-17','2022-10-18','2022-10-19','2022-10-20','2022-10-21','2022-10-22','2022-10-23','2022-10-24','2022-10-25','2022-10-26','2022-10-27','2022-10-28','2022-10-29','2022-10-30','2022-10-31','2022-11-01','2022-11-02','2022-11-03','2022-11-04','2022-11-05','2022-11-06','2022-11-07','2022-11-08','2022-11-09','2022-11-10','2022-11-11','2022-11-12','2022-11-13','2022-11-14','2022-11-15','2022-11-16','2022-11-17','2022-11-18','2022-11-19','2022-11-20','2022-11-21','2022-11-22','2022-11-23','2022-11-24','2022-11-25','2022-11-26','2022-11-27','2022-11-28','2022-11-29','2022-11-30','2022-12-01','2022-12-02','2022-12-03','2022-12-04','2022-12-05','2022-12-06','2022-12-07','2022-12-08','2022-12-09','2022-12-10','2022-12-11','2022-12-12','2022-12-13','2022-12-14','2022-12-15','2022-12-16','2022-12-17','2022-12-18','2022-12-19','2022-12-20','2022-12-21','2022-12-22','2022-12-23','2022-12-24','2022-12-25','2022-12-26','2022-12-27','2022-12-28','2022-12-29','2022-12-30','2022-12-31','2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05','2023-01-06','2023-01-07','2023-01-08','2023-01-09','2023-01-10','2023-01-11','2023-01-12','2023-01-13','2023-01-14','2023-01-15','2023-01-16','2023-01-17','2023-01-18','2023-01-19','2023-01-20','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-01-25','2023-01-26','2023-01-27','2023-01-28','2023-01-29','2023-01-30','2023-01-31']
appendDates = mdates.datestr2num(appendDates)

dates_covid19_dataset = [*dates_covid19_dataset, *appendDates]

plt.plot(dates_covid19_dataset, (I+R),'b', lw=2, label = 'Total accumulated of infected (model)')
plt.plot(dates_covid19_dataset, (R),'m', lw=2, label = 'Total accumulated of recovered (model)')
plt.legend()
plt.show()

# %% [markdown]
# Now using the same model, we'll project the accumulated deaths until 2023's January

# %%
dates_covid19_dataset = mdates.datestr2num(covid19_dataset['dt_referencia'].tolist())

fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

appendDates = ['2022-08-23', '2022-08-24', '2022-08-25','2022-08-26','2022-08-27','2022-08-28','2022-08-29','2022-08-30','2022-08-31','2022-09-01','2022-09-02','2022-09-03','2022-09-04','2022-09-05','2022-09-06','2022-09-07','2022-09-08','2022-09-09','2022-09-10','2022-09-11','2022-09-12','2022-09-13','2022-09-14','2022-09-15','2022-09-16','2022-09-17','2022-09-18','2022-09-19','2022-09-20','2022-09-21','2022-09-22','2022-09-23','2022-09-24','2022-09-25','2022-09-26','2022-09-27','2022-09-28','2022-09-29','2022-09-30','2022-10-01','2022-10-02','2022-10-03','2022-10-04','2022-10-05','2022-10-06','2022-10-07','2022-10-08','2022-10-09','2022-10-10','2022-10-11','2022-10-12','2022-10-13','2022-10-14','2022-10-15','2022-10-16','2022-10-17','2022-10-18','2022-10-19','2022-10-20','2022-10-21','2022-10-22','2022-10-23','2022-10-24','2022-10-25','2022-10-26','2022-10-27','2022-10-28','2022-10-29','2022-10-30','2022-10-31','2022-11-01','2022-11-02','2022-11-03','2022-11-04','2022-11-05','2022-11-06','2022-11-07','2022-11-08','2022-11-09','2022-11-10','2022-11-11','2022-11-12','2022-11-13','2022-11-14','2022-11-15','2022-11-16','2022-11-17','2022-11-18','2022-11-19','2022-11-20','2022-11-21','2022-11-22','2022-11-23','2022-11-24','2022-11-25','2022-11-26','2022-11-27','2022-11-28','2022-11-29','2022-11-30','2022-12-01','2022-12-02','2022-12-03','2022-12-04','2022-12-05','2022-12-06','2022-12-07','2022-12-08','2022-12-09','2022-12-10','2022-12-11','2022-12-12','2022-12-13','2022-12-14','2022-12-15','2022-12-16','2022-12-17','2022-12-18','2022-12-19','2022-12-20','2022-12-21','2022-12-22','2022-12-23','2022-12-24','2022-12-25','2022-12-26','2022-12-27','2022-12-28','2022-12-29','2022-12-30','2022-12-31','2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05','2023-01-06','2023-01-07','2023-01-08','2023-01-09','2023-01-10','2023-01-11','2023-01-12','2023-01-13','2023-01-14','2023-01-15','2023-01-16','2023-01-17','2023-01-18','2023-01-19','2023-01-20','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-01-25','2023-01-26','2023-01-27','2023-01-28','2023-01-29','2023-01-30','2023-01-31']
appendDates = mdates.datestr2num(appendDates)

dates_covid19_dataset = [*dates_covid19_dataset, *appendDates]

time_to_die = 5*7;

for i in range(0, len(dates_covid19_dataset)):
  dates_covid19_dataset[i] += time_to_die

mortality_rate = 120.3/100000

acc_death = I + R
acc_death *= mortality_rate

plt.plot(dates_covid19_dataset, acc_death,'k', lw=2, label = 'Total accumulated of deaths (model)')
plt.legend()
plt.show()

# %% [markdown]
# Now we will use the **SVIRS** without considering the vaccination. We created a new variable to store the total accumulated recovered, which has become susceptible again. We'll simulate the case in that the vaccines don't exist.

# %%
# Restoring the initial dates
dates_covid19_dataset = mdates.datestr2num(covid19_dataset['dt_referencia'].tolist())

# SVIRS model (not considering vaccination)

X0 = I0 + R0 # I0 -> initial value of total accumulated of infected | R0 -> initial value of total accumulated of recovered | X0 -> Initial value of total accumulated of recovered which have become susceptible again

def deriv(y, t, omegaR, gamma):
    if t < 70: # mid August 2020
      r = 0.069
    elif t < 160: # mid November 2020
      r = 0.06
    elif t < 170: # end of November 2020
      r = 0.13
    elif t < 380: # end of April 2021
      r = 0.069
    else:
      r = 0.053

    S, I, R, X = y # X is the variable that store the total accumulated recovered which have become susceptible
    beta = r/S
    
    lbda = beta

    dSdt = omegaR*R - lbda*S*I
    dIdt = lbda*S*I - gamma*I
    dRdt = gamma*I - omegaR*R
    dXdt = omegaR*R + gamma*I

    return dSdt, dIdt, dRdt, dXdt

# %%
# Applying the model:
y0 = S0, I0, R0, X0
t = np.linspace(0,len(dates_covid19_dataset),len(dates_covid19_dataset))

ret = odeint(deriv, y0, t, args=(omegaR, gamma))
S, I, R, X = ret.T

# %%
# Graphically representing the total accumulated of infected and comparing with reality
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

plt.plot(dates_covid19_dataset, (X + I),'b', lw=2, label = 'Total accumulated of infected (model)')
plt.plot(dates_covid19_dataset, totalOfInfecteds,'m', lw=2, label = 'Total accumulated of infected (reality)')
plt.legend()
plt.show()

# %% [markdown]
# Now we'll use our model that **does not** consider the vaccine to project the total accumulated of infected until January of 2023. As we did in last projection, we'll run the model until the last day of 2023's January using the same initial conditions.

# %%
t = np.linspace(0,len(dates_covid19_dataset)+162,len(dates_covid19_dataset)+162)

ret = odeint(deriv, y0, t, args=(omegaR, gamma))
S, I, R, X = ret.T

# %%
fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

appendDates = ['2022-08-23', '2022-08-24', '2022-08-25','2022-08-26','2022-08-27','2022-08-28','2022-08-29','2022-08-30','2022-08-31','2022-09-01','2022-09-02','2022-09-03','2022-09-04','2022-09-05','2022-09-06','2022-09-07','2022-09-08','2022-09-09','2022-09-10','2022-09-11','2022-09-12','2022-09-13','2022-09-14','2022-09-15','2022-09-16','2022-09-17','2022-09-18','2022-09-19','2022-09-20','2022-09-21','2022-09-22','2022-09-23','2022-09-24','2022-09-25','2022-09-26','2022-09-27','2022-09-28','2022-09-29','2022-09-30','2022-10-01','2022-10-02','2022-10-03','2022-10-04','2022-10-05','2022-10-06','2022-10-07','2022-10-08','2022-10-09','2022-10-10','2022-10-11','2022-10-12','2022-10-13','2022-10-14','2022-10-15','2022-10-16','2022-10-17','2022-10-18','2022-10-19','2022-10-20','2022-10-21','2022-10-22','2022-10-23','2022-10-24','2022-10-25','2022-10-26','2022-10-27','2022-10-28','2022-10-29','2022-10-30','2022-10-31','2022-11-01','2022-11-02','2022-11-03','2022-11-04','2022-11-05','2022-11-06','2022-11-07','2022-11-08','2022-11-09','2022-11-10','2022-11-11','2022-11-12','2022-11-13','2022-11-14','2022-11-15','2022-11-16','2022-11-17','2022-11-18','2022-11-19','2022-11-20','2022-11-21','2022-11-22','2022-11-23','2022-11-24','2022-11-25','2022-11-26','2022-11-27','2022-11-28','2022-11-29','2022-11-30','2022-12-01','2022-12-02','2022-12-03','2022-12-04','2022-12-05','2022-12-06','2022-12-07','2022-12-08','2022-12-09','2022-12-10','2022-12-11','2022-12-12','2022-12-13','2022-12-14','2022-12-15','2022-12-16','2022-12-17','2022-12-18','2022-12-19','2022-12-20','2022-12-21','2022-12-22','2022-12-23','2022-12-24','2022-12-25','2022-12-26','2022-12-27','2022-12-28','2022-12-29','2022-12-30','2022-12-31','2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05','2023-01-06','2023-01-07','2023-01-08','2023-01-09','2023-01-10','2023-01-11','2023-01-12','2023-01-13','2023-01-14','2023-01-15','2023-01-16','2023-01-17','2023-01-18','2023-01-19','2023-01-20','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-01-25','2023-01-26','2023-01-27','2023-01-28','2023-01-29','2023-01-30','2023-01-31']
appendDates = mdates.datestr2num(appendDates)

dates_covid19_dataset = [*dates_covid19_dataset, *appendDates]

plt.plot(dates_covid19_dataset, (X + I),'m', lw=2, label = 'Total accumulated of infected (model)')
plt.legend()
plt.show()

# %% [markdown]
# Now we'll project the accumulated deaths until 2023's January, using the same model

# %%
dates_covid19_dataset = mdates.datestr2num(covid19_dataset['dt_referencia'].tolist())

fig, ax = plt.subplots()
ax.xaxis_date()
fig.set_figwidth(10)
fig.set_figheight(5)

appendDates = ['2022-08-23', '2022-08-24', '2022-08-25','2022-08-26','2022-08-27','2022-08-28','2022-08-29','2022-08-30','2022-08-31','2022-09-01','2022-09-02','2022-09-03','2022-09-04','2022-09-05','2022-09-06','2022-09-07','2022-09-08','2022-09-09','2022-09-10','2022-09-11','2022-09-12','2022-09-13','2022-09-14','2022-09-15','2022-09-16','2022-09-17','2022-09-18','2022-09-19','2022-09-20','2022-09-21','2022-09-22','2022-09-23','2022-09-24','2022-09-25','2022-09-26','2022-09-27','2022-09-28','2022-09-29','2022-09-30','2022-10-01','2022-10-02','2022-10-03','2022-10-04','2022-10-05','2022-10-06','2022-10-07','2022-10-08','2022-10-09','2022-10-10','2022-10-11','2022-10-12','2022-10-13','2022-10-14','2022-10-15','2022-10-16','2022-10-17','2022-10-18','2022-10-19','2022-10-20','2022-10-21','2022-10-22','2022-10-23','2022-10-24','2022-10-25','2022-10-26','2022-10-27','2022-10-28','2022-10-29','2022-10-30','2022-10-31','2022-11-01','2022-11-02','2022-11-03','2022-11-04','2022-11-05','2022-11-06','2022-11-07','2022-11-08','2022-11-09','2022-11-10','2022-11-11','2022-11-12','2022-11-13','2022-11-14','2022-11-15','2022-11-16','2022-11-17','2022-11-18','2022-11-19','2022-11-20','2022-11-21','2022-11-22','2022-11-23','2022-11-24','2022-11-25','2022-11-26','2022-11-27','2022-11-28','2022-11-29','2022-11-30','2022-12-01','2022-12-02','2022-12-03','2022-12-04','2022-12-05','2022-12-06','2022-12-07','2022-12-08','2022-12-09','2022-12-10','2022-12-11','2022-12-12','2022-12-13','2022-12-14','2022-12-15','2022-12-16','2022-12-17','2022-12-18','2022-12-19','2022-12-20','2022-12-21','2022-12-22','2022-12-23','2022-12-24','2022-12-25','2022-12-26','2022-12-27','2022-12-28','2022-12-29','2022-12-30','2022-12-31','2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05','2023-01-06','2023-01-07','2023-01-08','2023-01-09','2023-01-10','2023-01-11','2023-01-12','2023-01-13','2023-01-14','2023-01-15','2023-01-16','2023-01-17','2023-01-18','2023-01-19','2023-01-20','2023-01-21','2023-01-22','2023-01-23','2023-01-24','2023-01-25','2023-01-26','2023-01-27','2023-01-28','2023-01-29','2023-01-30','2023-01-31']
appendDates = mdates.datestr2num(appendDates)

dates_covid19_dataset = [*dates_covid19_dataset, *appendDates]

time_to_die = 5*7;

for i in range(0, len(dates_covid19_dataset)):
  dates_covid19_dataset[i] += time_to_die

mortality_rate = 120.3/100000

acc_death = (X + I)
acc_death *= mortality_rate

plt.plot(dates_covid19_dataset, acc_death,'k', lw=2, label = 'Total accumulated of deaths (model)')
plt.legend()
plt.show()

# %% [markdown]
# The first model that we used, which considers the vaccine, was completely based on the **SVIRS** model, an existing model. But, for the second model, we modified the **SVIRS** model and created a new one to fulfill our goals and necessities.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# By analysis of the generated graphs, we can notice that without vaccination we have a higher number of infected people, as expected. Our model that considers the vaccination seems to deliver results that match the reality of COVID-19 in PE. We did some projections from 2020's April until 2023's January about COVID-19 using our models.

# %% [markdown]
# ## References

# %% [markdown]
# *   [https://www.lai.pe.gov.br/ses/transparencia-da-vacinacao-covid-19/](https://www.lai.pe.gov.br/ses/transparencia-da-vacinacao-covid-19/)
# * [https://covid.saude.gov.br/](https://covid.saude.gov.br/)
# * [https://www.uol.com.br/vivabem/noticias/redacao/2021/08/25/eficacia-das-vacinas-coronavac-astrzeneca-pfizer-e-janssen.htm](https://www.uol.com.br/vivabem/noticias/redacao/2021/08/25/eficacia-das-vacinas-coronavac-astrzeneca-pfizer-e-janssen.htm)
# * [https://www.ibge.gov.br/cidades-e-estados/pe.html](https://www.ibge.gov.br/cidades-e-estados/pe.html)
# * [https://www.ajmc.com/view/a-timeline-of-covid-19-vaccine-developments-in-2021](https://www.ajmc.com/view/a-timeline-of-covid-19-vaccine-developments-in-2021)
# * [https://www.fda.gov/news-events/press-announcements/fda-approves-first-covid-19-vaccine](https://www.fda.gov/news-events/press-announcements/fda-approves-first-covid-19-vaccine)
# * [https://especiais.g1.globo.com/bemestar/vacina/2021/mapa-brasil-vacina-covid/](https://especiais.g1.globo.com/bemestar/vacina/2021/mapa-brasil-vacina-covid/)
# * [https://g1.globo.com/pe/pernambuco/noticia/2022/01/29/pernambuco-registra-6581-casos-de-covid-e-bate-recorde-de-confirmacoes-de-toda-a-pandemia.ghtml](https://g1.globo.com/pe/pernambuco/noticia/2022/01/29/pernambuco-registra-6581-casos-de-covid-e-bate-recorde-de-confirmacoes-de-toda-a-pandemia.ghtml)
# * [https://link.springer.com/content/pdf/10.1007/s10665-020-10037-8.pdf](https://link.springer.com/content/pdf/10.1007/s10665-020-10037-8.pdf)
# *[https://g1.globo.com/bemestar/coronavirus/noticia/2020/08/19/brasil-mostra-desaceleracao-na-taxa-de-transmissao-da-covid-19-pela-primeira-vez-desde-abril-aponta-imperial-college.ghtml](https://link.springer.com/content/pdf/10.1007/s10665-020-10037-8.pdf)
# *[https://g1.globo.com/bemestar/coronavirus/noticia/2020/11/10/taxa-estimada-de-transmissao-do-novo-coronavirus-no-brasil-tem-menor-taxa-desde-abril.ghtml](https://g1.globo.com/bemestar/coronavirus/noticia/2020/11/10/taxa-estimada-de-transmissao-do-novo-coronavirus-no-brasil-tem-menor-taxa-desde-abril.ghtml)
# *[https://g1.globo.com/bemestar/coronavirus/noticia/2020/11/24/taxa-de-transmissao-da-covid-19-no-brasil-e-a-maior-desde-maio-aponta-imperial-college.ghtml](https://g1.globo.com/bemestar/coronavirus/noticia/2020/11/24/taxa-de-transmissao-da-covid-19-no-brasil-e-a-maior-desde-maio-aponta-imperial-college.ghtml)
# *[https://g1.globo.com/saude/coronavirus/noticia/2021/10/26/taxa-de-transmissao-do-coronavirus-no-brasil-segue-baixa-aponta-imperial-college.ghtml](https://g1.globo.com/saude/coronavirus/noticia/2021/10/26/taxa-de-transmissao-do-coronavirus-no-brasil-segue-baixa-aponta-imperial-college.ghtml)
# * [https://www.thelancet.com/article/S0140-6736(21)02796-3/fulltext](https://www.thelancet.com/article/S0140-6736(21)02796-3/fulltext)
# * [https://ourworldindata.org/covid-deaths](https://ourworldindata.org/covid-deaths)
